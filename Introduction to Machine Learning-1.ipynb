# %% [markdown]
# # Assignment: Introduction to Machine Learning-1

# %% [markdown]
# ### Q1- Explain the following with an Example.

# %% [markdown]
# * Artificial Intelligence : An Smart Application that cxan perform it's own task without human intervention.
#
#      _Example : Self Driving Cars, Robots, Alexa, Siri, etc.._
#
# * Machine Learning : It is a subset of Artificial intelligence. It provides statstools to analyze and visualize data, create predictive models, forcasting models, etc.
#
#      _Example : Recommendation System of Amazon.in and Netflix._
#
# * Deep Learning : A subset of Machine Learning. Multi-layered Nueral Network. Made to Mimic the human brain.
#
#     _Example  : Object Detection, Image Recognition, ChatBots, etc._

# %% [markdown]
# ### Q2- What is supervised learning? List some examples of supervised learning.

# %% [markdown]
# Supervised learning, also known as supervised machine learning, is a subcategory of machine learning and artificial intelligence. It is defined by its use of labeled datasets to train algorithms that to classify data or predict outcomes accurately.
# ![What-is-supervised-learning.jpg.webp](attachment:fa37133d-3014-4051-b30a-9240ab0e8ff8.webp)
#
# As we can see in the above picture the model is classifying different groups. It is an example of Classification.
#
#
# Now, lets see an example of regression.
# Regression includes continuous output feature.
#
# ![data-sources-6340899b3c.png](attachment:11603330-d00a-4f0d-a6cb-3fb1abe94133.png)
#
# The above picture is an example of regression, the Price of the house is a Output Feature and a Continuous Value. It depends on the various other factors such as no. of rooms, size of the house, locality, etc.
#
# Now, lets see an example of Semi-Supervised Learning
#
# ![ssl-pseudo-label.png](attachment:5ba023f1-c0eb-420e-97aa-6bf92c53fa86.png)
#
# Semi-Supervised Learning = Supervised Learning + Unsupervised Learning
#
#
# Now, lets see an example of Reinforcement Learning.
#
# Reinforcement learning (RL) is an area of machine learning concerned with how intelligent agents ought to take actions in an environment in order to maximize the notion of cumulative reward.
#
# ![download.png](attachment:88940c29-3575-4bc4-8d83-e3d4bab84114.png)

# %% [markdown]
# ### Q3-What is unsupervised learning? List some examples of unsupervised learning.

# %% [markdown]
# Unsupervised learning is when it can provide a set of unlabelled data, which it is required to analyze and find patterns inside. The examples are dimension reduction and clustering.An example of unsupervised machine learning would be a case where a supermarket wants to increase its revenue. It decides to implement a machine learning algorithm on its sold products' data. It was observed that the customers who bought cereals more often tend to buy milk or those who buy eggs tend to buy bacon.
#
# ![download.png](attachment:bd045cce-e45d-4a93-8ee7-22516f8b5a82.png)
# ![download.png](attachment:40579e1f-9172-4da5-8c3e-d470e0c91ffa.png)

# %% [markdown]
# ### Q4- What is the difference between AI, ML, DL, and DS?
# ![download.jpg](attachment:3a99b26c-dc89-40af-9fb3-3eda85699f8c.jpg)
#
# Artificial Intelligence : An Smart Application that cxan perform it's own task without human intervention.
#
#
# Machine Learning : It is a subset of Artificial intelligence. It provides statstools to analyze and visualize data, create predictive models, forcasting models, etc.
#
#
# Deep Learning : A subset of Machine Learning. Multi-layered Nueral Network. Made to Mimic the human brain.
#
# Data Science :Data science is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data.

# %% [markdown]
# ### Q5- What are the main differences between supervised, unsupervised, and semi-supervised learning?
#
# ![download.png](attachment:5a0a0c52-b8c0-41d4-ac27-f2743658ecd6.png)
#
# A problem that sits in between supervised and unsupervised learning called semi-supervised learning.The main difference between these types is the level of availability of ground truth data, which is prior knowledge of what the output of the model should be for a given input.
#
# Supervised learning aims to learn a function that, given a sample of data and desired outputs, approximates a function that maps inputs to outputs.
# Semi-supervised learning aims to label unlabeled data points using knowledge learned from a small number of labeled data points.
# Unsupervised learning does not have (or need) any labeled outputs, so its goal is to infer the natural structure present within a set of data points.

# %% [markdown]
# ### Q6- What is train, test and validation split? Explain the importance of each term.
#
# * Training Dataset
#
# The difference between the training set and the validation set is the training set is the largest corpus of your dataset that you reserve for training your model. After training, inference on these images will be taken with a grain of salt, since the model has already had a chance to look at and memorize the correct output.
#
# * Validation Dataset
#
# The validation set is a separate section of your dataset that you will use during training to get a sense of how well your model is doing on images that are not being used in training.
#
# During training, it is common to report validation metrics continually after each training epoch such as validation mAP or validation loss. You use these metrics to get a sense of when your model has hit the best performance it can reach on your validation set. You may choose to cease training at this point, a process called "early stopping."
#
# * Test Dataset
#
# After all of the training experiments have concluded, you probably have gotten a sense on how your model might do on the validation set. But it is important to remember that the validation set metrics may have influenced you during the creation of the model, and in this sense you might, as a designer, overfit the new model to the validation set.
#
# Because the validation set is heavily used in model creation, it is important to hold back a completely separate stronghold of data - the test set. You can run evaluation metrics on the test set at the very end of your project, to get a sense of how well your model will do in production.

# %% [markdown]
# ### Q7- How can unsupervised learning be used in anomaly detection?

# %% [markdown]
# * Unsupervised learning algorithms can be used to identify data points that are significantly different from the rest of the data.
#
# * Some of the most common unsupervised learning algorithms for anomaly detection include K-means clustering, Gaussian mixture models, and isolation forest.
#
# * The choice of which algorithm to use depends on the specific application.
#
# * Unsupervised learning can be a powerful tool for anomaly detection, but it is important to note that the results can be sensitive to the data distribution.

# %% [markdown]
# ### Q8- List down some commonly used supervised learning algorithms and unsupervised learning algorithms.

# %% [markdown]
# Some commonly used supervised learning algorithms:
#
# * **Linear regression:** This algorithm is used to predict a continuous value, such as price or weight.
# * **Logistic regression:** This algorithm is used to predict a binary value, such as yes or no.
# * **Decision trees:** This algorithm is used to predict a value by splitting the data into smaller and smaller groups.
# * **Support vector machines:** This algorithm is used to find the best hyperplane to separate two classes of data.
# * **Naive Bayes:** This algorithm is used to predict a value by calculating the probability of each class.
#
# Some commonly used unsupervised learning algorithms:
#
# * **K-means clustering:** This algorithm is used to group data points together based on their similarity.
# * **Gaussian mixture models:** This algorithm assumes that the data is normally distributed and groups data points together based on their normal distribution.
# * **Hierarchical clustering:** This algorithm builds a tree of clusters, where each cluster is a child of another cluster.
# * **Principal component analysis:** This algorithm reduces the dimensionality of data by finding the most important features.
# * **Association rule mining:** This algorithm finds rules that describe how often items are bought together.
#
# The choice of which algorithm to use depends on the specific problem. For example, if you are trying to predict the price of a house, you would use a linear regression algorithm. If you are trying to predict whether someone will click on an ad, you would use a logistic regression algorithm.
#
# It is important to note that supervised and unsupervised learning algorithms can be used together. For example, you could use a supervised learning algorithm to predict the value of a house, and then use an unsupervised learning algorithm to cluster the houses into different groups.

# %% [markdown]
# ## THE END
